# %% [markdown]
# <a href="https://colab.research.google.com/github/DouglasP15/Treinamento-Phyton-Generation-/blob/main/Calculadora.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importando bibliotecas
# lembrando! se não estamos no colab, devemos
# fazer o comando pip install NOME_DA_BIBLIOTECA
import numpy as np
#numpy é a biblioteca de funçoes matematicas
#np é o apelido que usamos para ela

# %%
# sem usar o numpy
# matemática básica
numero1 = float(input('informe o primeiro número'))
numero2 = float(input('informe o segundo número'))

# soma
soma = numero1 + numero2
print(soma)
# subtração
subtracao = numero1 - numero2
print(subtracao)
# divisão
divi = numero1/numero2
print(divi)
#multiplicação
multi = numero1 * numero2
print(multi)
# Out:
# informe o primeiro número5
# informe o segundo número7
# 12.0
# -2.0
# 0.7142857142857143
# 35.0

# %%
# com numpy
# matematica basica
numero1 = float(input('informe o primeiro numero '))
numero2 = float(input('informe o segundo numero'))

#soma poder ser add ou sum(apenas numeros inteiros)
print(f'soma:{np.add(numero1,numero2)}')
#ou o método sum - só numeros inteiros
# print(f'soma: {np.sum(numero1,numero2')})

#subtrair
print(f'subtração: {np.subtract(numero1,numero2)}')
#multiplicar
print(f'multiplicação: {np.multiply(numero1,numero2)}')
#dividir
print(f'divisão: {np.divide(numero1,numero2)}')
# Out:
# informe o primeiro numero 7
# informe o segundo numero9
# soma:16.0
# subtração: -2.0
# multiplicação: 63.0
# divisão: 0.7777777777777778

# %%
while True:
  #while True não necessita de uma condição para inicio ou fim
  #---------
  # para finalizar o while true usamos o caso BREAK
  print('----CALCULADORA----')
  print('1 - somar')
  print('2 - subtrair')
  print('3 - multiplicar')
  print('4 - dividir')
  print('0 - sair')

  op = input('escolha a opção')

  if op == "0":
    break
  elif op == '1':
    print(soma)
  elif op == '2':
    print(subtracao)
  elif op == '3':
    print(multi)
  elif op == '4':
    print(divi)
  else:
    print('Opção não encontrada')
# Out:
# ----CALCULADORA----
# 1 - somar
# 2 - subtrair
# 3 - multiplicar
# 4 - dividir
# 0 - sair
# escolha a opção0

# %%
#usando sistema de CAIXA DE SUPERMERCADO
#quais elementos tem o pagamento?

#temos produtos
#temos quantidades
#temos um total
# temos produtos
# temos quantidades
# temos um total
lista_nome = []
lista_quantidade = []
lista_valor = []
while True:

  op_tem = input('Tem algum produto para passar? S/N')
  if op_tem.lower() == 'n':
    print('sistema finalizado')
    break
  elif op_tem.lower() == 's':
    while True:
      # precisamos de variaveis
      # precisamos de listas

      nome = input('Qual o produto?')
      valor = float(input('Qual o valor'))
      quantidade = float(input('Qual a qunatidade'))
      lista_nome.append(nome)
      lista_valor.append(valor)
      lista_quantidade.append(quantidade)

      op_novo_produto = input('tem outro produto? S/N')

      if op_novo_produto.lower() == 'n':
          print('indo para a nota fical')
          # vai ter coisas aqui
          print('---- CUMPOM FISCAL ----')
          print('Produto | Valor | Quantidade | Total')
          # i - produto --- j - valor ----- k - quantidade ---- l - total
          # o total é uma multiplicação - valor e a quantidade
          # transformar a lista em numpy
          np_valor = np.array(lista_valor)
          np_quantidade = np.array(lista_quantidade)
          # np.array() - transforma um conjunto de numeros para numpy
          total = np.multiply(np_valor, np_quantidade)
          for i,j,k,l in zip(lista_nome, lista_valor, lista_quantidade,total):
            print(f'{i} -- {j} -- {k} -- {l}')
          break
      else:
          print('informe o novo produto')
# Out:
# Tem algum produto para passar? S/Ns
# Qual o produto?sjdja
# Qual o valor50
# Qual a qunatidade2
# tem outro produto? S/Nn
# indo para a nota fical
# ---- CUMPOM FISCAL ----
# Produto | Valor | Quantidade | Total
# sjdja-- 50.0 -- 2.0 -- 100.0
# Tem algum produto para passar? S/Nn
# sistema finalizado
